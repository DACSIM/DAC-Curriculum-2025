# %% [markdown]
# # 🧠 Learn SQL the Fun Way!
# Welcome to your beginner-friendly **SQL tutorial** — right inside Google Colab!
#
# In this notebook, we'll use **SQLite** (a lightweight database built into Python)** and learn SQL basics step-by-step — by actually running real queries.
#
# Let's get started 🚀

# %%
# @title
# !pip install ipython-sql==0.5.0 prettytable==3.9.0
# %load_ext sql
# %sql sqlite://
# %config SqlMagic.style = 'PLAIN_COLUMNS'  # safe style
# %config SqlMagic.autopandas = True
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %reload_ext sql

# %% [markdown]
# ## 🧩 Setting Up a Simple Database
# Let's create a small **Driver Database** with two tables: `driver` and `team`.

# %%
# %%sql
#
# DROP TABLE IF EXISTS drivers;
# DROP TABLE IF EXISTS team;
#
# CREATE TABLE drivers (
#     id INTEGER PRIMARY KEY,
#     name TEXT,
#     age INTEGER,
#     races  INTEGER,
#     team_id INTEGER
# );
#
# CREATE TABLE team (
#     id INTEGER PRIMARY KEY,
#     team_name TEXT,
#     team_principal TEXT
# );
#
# INSERT INTO team VALUES
# (1, 'Red Bull', 'Laurent Mekies'),
# (2, 'Ferrari', 'Fred Vasseur'),
# (3, 'McLaren', 'Andrea Stella');
#
# INSERT INTO drivers VALUES
# (1, 'Max Verstappen', 28, 227, 1),
# (3, 'Daniel Ricciardo', 36, 257, 1),
# (16, 'Charles Leclerc', 27, 165, 2),
# (44, 'Lewis Hamilton', 40, 374, 2),
# (81, 'Oscar Piastri', 24, 64, 3);
# Out:
#  * sqlite://
# Done.
# Done.
# Done.
# Done.
# 3 rows affected.
# 5 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 👀 SELECT Basics
# `SELECT` is how we ask questions in SQL. Think of it as saying: *“Hey database, show me this info!”*

# %%
# %%sql
# # Show the drivers table

# %%
# %%sql
# # Show the team table

# %% [markdown]
# ### 🎯 Selecting specific columns
# You can pick specific columns instead of everything using `SELECT column1, column2`. Try it below 👇

# %%
# %%sql
# SELECT name, races FROM drivers;
# Out:
#  * sqlite://
# Done.
#                name  races
# 0    Max Verstappen    227
# 1  Daniel Ricciardo    257
# 2   Charles Leclerc    165
# 3    Lewis Hamilton    374
# 4     Oscar Piastri     64

# %% [markdown]
# ### 🧠 Try it yourself:
# Select only the driver names and ages.

# %%
# %%sql
# -- Select name and age from the driver table!
# Out:
#  * sqlite://
# Done.
#                name  age
# 0    Max Verstappen   28
# 1  Daniel Ricciardo   36
# 2   Charles Leclerc   27
# 3    Lewis Hamilton   40
# 4     Oscar Piastri   24

# %% [markdown]
# ## 🎯 Filtering Data with WHERE
# Use `WHERE` to filter results — it’s like setting conditions.

# %%
# %%sql
# -- Drivers with more than 150 race starts
# Out:
#  * sqlite://
# Done.
#                name  races
# 0    Max Verstappen    227
# 1  Daniel Ricciardo    257
# 2   Charles Leclerc    165
# 3    Lewis Hamilton    374

# %% [markdown]
# ### 🔍 LIKE and Wildcards
# You can use `LIKE` to find text patterns — `%` means 'anything'. For example, find drivers with names starting with 'M':

# %%
# %%sql
# # Select drivers starting with 'M'

# %% [markdown]
# ## 📊 Sorting and Limiting Results
# Use `ORDER BY` to sort, and `LIMIT` to control how many rows you see.

# %%
# %%sql
# -- Sort drivers by races
# Out:
#  * sqlite://
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 🧮 Aggregates and GROUP BY
# SQL can summarize data using functions like `COUNT`, `AVG`, `SUM`, etc.

# %%
# %%sql
# -- Average race starts by team

# %% [markdown]
# ## 🤝 Understanding JOINs
# JOINs connect related tables together. For example, combine `drivers` and `teams` to see each driver's team name.

# %% [markdown]
# ![datalemur sql joins venn diagram.png](data:image/png;base64,...)

# %%
# %%sql
# # See each drivers team name

# %% [markdown]
# ## 🧩 Subqueries — Queries inside Queries
# You can nest a query inside another. Example: Find drivers who've raced above the average number.

# %%
# %%sql
#
# #Find drivers who have races above the average number of races

# %% [markdown]
# ## 🏁 Practice Time
# ### Try these mini challenges:
# 1. Show all drivers in Red Bull.
# 2. Find the youngest driver.
# 3. Show average age per team, highest first.

# %%
# %%sql
# -- Your turn! Practice below 👇
# Out:
#  * sqlite://
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 💡 Common SQL Mistakes and Tips
# Here are some common beginner mistakes (and how to fix them):
#
# 1. ❌ **Forgetting WHERE in DELETE/UPDATE** → Always check before you run it!
# 2. ❌ **Using = NULL** → Use `IS NULL` or `IS NOT NULL` instead.
# 3. ❌ **Mixing up INNER vs LEFT JOIN** → INNER shows matches only; LEFT keeps all from the left table.
# 4. ❌ **GROUP BY without aggregates** → Only use `GROUP BY` with functions like `COUNT`, `AVG`, etc.
# 5. ❌ **Forgetting quotes** → Strings go in single quotes `'like this'`.
# 6. 💡 **Pro Tip:** When exploring a new table, use `LIMIT 5` to avoid huge outputs!
#
# You’re now ready to teach SQL like a pro! 🎓
